# %%
import numpy as np
import pandas as pd

data = {'name'  : ['Jack', 'Bill', 'Phic', 'Tao'], 'grade' : [9.8, 4.5, 7.7, 9.4] }
df = pd.DataFrame(data)
print ( df)
# Out:
#    name  grade
# 0  Jack    9.8
# 1  Bill    4.5
# 2  Phic    7.7
# 3   Tao    9.4

# %%
wines = pd.read_csv('winequality-red.csv', sep = ';')
wines.head()
wines.columns
wines.info()
wines.mean() # avg value of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# fixed acidity            8.319637
# volatile acidity         0.527821
# ...

# %%
wines[['pH', 'alcohol', 'quality']].head() # lấy nhiều cột thì phải dùng list 
wines.describe().T # .T transpose matrix 
# xóa cột : df.pop()
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
data = {'name'  : ['Jack', 'Bill', 'Phic', 'Tao'], 'grade' : [9.8, 4.5, 7.7, 9.4] }
df = pd.DataFrame(data)
#print (df)
# add new column
df['age'] = [15, 16, 16, 18]

#print ( df )
df.loc[0, 'grade'] = 8.9 # tham chiếu theo dòng-- lấy info của hàng 0 cột grade 
# loc cho phép dùng index hàng là str
data = {'name'  : ['Jack', 'Bill', 'Phic', 'Tao'], 'grade' : [9.8, 4.5, 7.7, 9.4] ,'code' :['id1', 'id2', 'id3', 'id4']}
df2 = pd.DataFrame(data)
#df2.loc['id2', 'grade'] = 8.9
print ( df2 )
df2.set_index('code')

# thêm dòng dùng append
# Out:
#    name  grade code
# 0  Jack    9.8  id1
# 1  Bill    4.5  id2
# 2  Phic    7.7  id3
# 3   Tao    9.4  id4
#       name  grade
# code
# id1   Jack    9.8
# id2   Bill    4.5
# id3   Phic    7.7
# id4    Tao    9.4

# %%
wines['quality'].value_counts()
# group wines by quality 

wines[wines.quality == 3].sort_values(by = 'fixed acidity', ascending= False)
# xác định lại nhãn dòng dùng set_index
#df.set_index

df.iloc[:2, :3] # iloc index dùng dạng số, hàng trước cột sau 
#df.loc[:, :3] # loc không dùng được để slicing dùng số cho tên cột 

wines[(wines['quality'] >= 3) & (wines['quality'] <= 5) & (wines['fixed acidity'] >= 10)]
# lọc dữ liệu theo điều kiện
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 56             10.2              0.42         0.57             3.4      0.070
# 252            11.1              0.35         0.48             3.1      0.090
# 264            12.5              0.56         0.49             2.4      0.064
# 272            10.9              0.37         0.58             4.0      0.071
# 289            11.6              0.42         0.53             3.3      0.105
# ...             ...               ...          ...             ...        ...
# 1414           10.0              0.32         0.59             2.2      0.077
# 1416           10.0              0.32         0.59             2.2      0.077
# 1436           10.0              0.38         0.38             1.6      0.169
# 1470           10.0              0.69         0.11             1.4      0.084
# 1548           11.2              0.40         0.50             2.0      0.099
#
# ...
